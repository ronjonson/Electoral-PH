# %%
from openpyxl import load_workbook
import pandas as pd

# %%
excel_dir = r'C:\Users\Neil\Documents\Projects\Electoral-PH\Electoral-PH\image_creator\static\PH_Electoral.xlsx'

# %%
wb = load_workbook(excel_dir)

# %%
wb.sheetnames
# Out:
# ['test',
#  'Provinces',
#  'Candidates',
#  '2004_Reps',
#  '2004_Presidential',
#  '2010_Reps',
#  '2010_Presidential',
#  '2010_VicePresidential',
#  '2016_Reps',
#  '2016_Presidential',
#  '2016_VicePresidential',
#  '2022_Reps',
#  '2022_Presidential',
#  '2022_VicePresidential']

# %%
save_dir = r'C:\Users\Neil\Documents\Projects\Electoral-PH\Electoral-PH\image_creator\static\data'

# %%
for sheet_name in wb.sheetnames:
    df = pd.read_excel(excel_dir, sheet_name=sheet_name)
    df.to_csv(save_dir+'/'+sheet_name+'.csv')
